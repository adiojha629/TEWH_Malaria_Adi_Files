# %% [markdown]
# <a href="https://colab.research.google.com/github/adiojha629/TEWH_Malaria_Adi_Files/blob/master/Dropout%2C_Dense%2C_and_Activation_Experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Model Evaluation Framework
# Here we setup a framework for running model experiments.

# %% [markdown]
# ## Import Raw Dataset
# On the right-hand side of this page, you will see a folders symbol. If you click on it and then click on "refresh", you should be able to see the files on this Google Colab document.
#
#
# Here we import the NIH malaria dataset from the website, with the terminal command ```!wget```. Then we extract the images into our temporary file directory called ```/content```. Specifically, we load these images in a folder called ```/content/cell_images```. It is not too important to understand this code chunk, since it will remain virtually unchanged for the entire project.

# %%
# Import relevant packages for image file importation 
import numpy as np
import os
from shutil import copyfile
from zipfile import ZipFile

# Here we download the NIH dataset as a zip file
# !wget -nc ftp://lhcftp.nlm.nih.gov/Open-Access-Datasets/Malaria/cell_images.zip

# Extract images if not already extracted
ROOT_DIR = os.path.join("/", "content")
if not os.path.isdir("cell_images"):
    print("Extracting images...")
    with ZipFile(os.path.join(ROOT_DIR, "cell_images.zip"), "r") as zipObj:
        zipObj.extractall()
    print("Done!")
# Out:
# --2020-08-04 22:04:34--  ftp://lhcftp.nlm.nih.gov/Open-Access-Datasets/Malaria/cell_images.zip
#            => ‘cell_images.zip’
# Resolving lhcftp.nlm.nih.gov (lhcftp.nlm.nih.gov)... 130.14.55.35, 2607:f220:41e:7055::35
# Connecting to lhcftp.nlm.nih.gov (lhcftp.nlm.nih.gov)|130.14.55.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Open-Access-Datasets/Malaria ... done.
# ==> SIZE cell_images.zip ... 353452851
# ==> PASV ... done.    ==> RETR cell_images.zip ... done.
# Length: 353452851 (337M) (unauthoritative)
#
# cell_images.zip     100%[===================>] 337.08M   484KB/s    in 4m 28s
#
# 2020-08-04 22:09:03 (1.26 MB/s) - ‘cell_images.zip’ saved [353452851]
#
# Extracting images...
# Done!

# %% [markdown]
# ## Load and Resize Images into NumPy Arrays
# Here we create some a new folder called ```RescaledSet``` to store our resized images of our parasitized and uninfected cells.
#
#
# We rescale all of the images to 128x128 pixels with RGB channels.
#
#
# The parasitized images will be stored in the NumPy array called ```Parasitized```, while the uninfected images will be stored in the NumPy array called ```Uninfected```.
#
# For testing purposes, we only rescale 500 images for each class.
# When the program is run on the Google Cloud, then we will rescale all the images.

# %%
# Create new folders to save rescaled images
# Create new directory called "test_folder"
if not os.path.isdir("RescaledSet"):
  os.mkdir("/content/RescaledSet")
if not os.path.isdir("RescaledSet/Parasitized"):
  os.mkdir("/content/RescaledSet/Parasitized")
if not os.path.isdir("RescaledSet/Uninfected"):
  os.mkdir("/content/RescaledSet/Uninfected")

# Generate list of parasitized file names
import os
ParasitizedFiles = os.listdir("/content/cell_images/Parasitized/")
UninfectedFiles = os.listdir("/content/cell_images/Uninfected/")

import numpy as np
import cv2
from PIL import Image

# Short-version for testing
Parasitized = np.empty([500,128,128,3])
Uninfected = np.empty([500,128,128,3])

for i in range(0,500):
  # Import image as np.array
  TempImage = cv2.imread('/content/cell_images/Parasitized/'+ParasitizedFiles[i])
  # Resize image to 128x128 pixels
  ResizedImage = cv2.resize(TempImage, dsize=(128,128))
  # Save image in folder 
  Parasitized[i,:,:,:] = ResizedImage

for i in range(0,500):
  # Import image as np.array
  TempImage = cv2.imread('/content/cell_images/Uninfected/'+UninfectedFiles[i])
  # Resize image to 128x128 pixels
  ResizedImage = cv2.resize(TempImage, dsize=(128,128))
  # Save image in folder 
  Uninfected[i,:,:,:] = ResizedImage

"""The code below will be run on Google Cloud. The code rescales all the images"""
#Parasitized = np.empty([13779,128,128,3])
#Uninfected = np.empty([13779,128,128,3])

# May have to remove some thumbs.db files (i = 10394 for parasitized and 1 = 10392 for uninfected)
#for i in range(0,10394):
#  # Import image as np.array
#  TempImage = cv2.imread('/content/cell_images/Parasitized/'+ParasitizedFiles[i])
#  # Resize image to 128x128 pixels
#  ResizedImage = cv2.resize(TempImage, dsize=(128,128))
#  # Save image in folder 
#  Parasitized[i,:,:,:] = ResizedImage

#for i in range(10395,13780):
#  # Import image as np.array
#  TempImage = cv2.imread('/content/cell_images/Parasitized/'+ParasitizedFiles[i])
#  # Resize image to 128x128 pixels
#  ResizedImage = cv2.resize(TempImage, dsize=(128,128))
#  # Save image in folder 
#  Parasitized[i-1,:,:,:] = ResizedImage

#for i in range(0,10392):
#  # Import image as np.array
#  TempImage = cv2.imread('/content/cell_images/Uninfected/'+UninfectedFiles[i])
#  # Resize image to 128x128 pixels
#  ResizedImage = cv2.resize(TempImage, dsize=(128,128))
#  # Save image in folder 
#  Uninfected[i,:,:,:] = ResizedImage

#for i in range(10393,13780):
#  # Import image as np.array
#  TempImage = cv2.imread('/content/cell_images/Uninfected/'+UninfectedFiles[i])
#  # Resize image to 128x128 pixels
#  ResizedImage = cv2.resize(TempImage, dsize=(128,128))
#  # Save image in folder 
#  Uninfected[i-1,:,:,:] = ResizedImage
# Out:
# 'The code below will be run on Google Cloud. The code rescales all the images'

# %% [markdown]
# ## Split Data into Five Groups for Cross-Validation
# We will be using ```k=5``` cross-validation groups.

# %%
# Number of cross-validation groups 
k = 5

# Generate dataset labels
ParasitizedLabels = np.repeat([[0,1]], 500, axis=0)
UninfectedLabels = np.repeat([[1,0]], 500, axis=0)
Labels = np.concatenate((ParasitizedLabels,UninfectedLabels), axis=0)

# Generate image dataset
Dataset = np.concatenate((Parasitized, Uninfected), axis=0)

# Generate cross-validation groups
CVIndices = np.random.permutation(Dataset.shape[0]) #CVIndices gets random, non-repeating numbers from 0 to the n, where n is the number of images in our dataset
#Index-n holds the indices of the images in the Dataset that go in to the n-th crossvalidation group
Index1, Index2, Index3, Index4, Index5 = CVIndices[:200], CVIndices[200:400], CVIndices[400:600], CVIndices[600:800], CVIndices[800:]
#Using the Index variables above we get the images and labels for each cross validation group.
Images1, Images2, Images3, Images4, Images5 = Dataset[Index1,:], Dataset[Index2,:], Dataset[Index3,:], Dataset[Index4,:], Dataset[Index5,:]
Labels1, Labels2, Labels3, Labels4, Labels5 = Labels[Index1,:], Labels[Index2,:], Labels[Index3,:], Labels[Index4,:], Labels[Index5,:]

# %% [markdown]
# ## Train model with different hyperparameters and Cross-Validation Groups

# %%
# Libraries needed
import sys
if 'tensorflow' in sys.modules == False:
  # %tensorflow_version 2.x
  import tensorflow as tf
import keras
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, BatchNormalization
from keras import backend as k 
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping

import warnings
warnings.filterwarnings('ignore')

List_Dropout_Rates = [0.25,0.50,0.75] #all the drop out rates used
List_Dense = [128,256,512,1024] #number of neurons in Dense layer
List_Activation = ["relu","tanh"] #the different activation functions used

results = []# This list will contain the Loss, Accuracy, Validation Loss etc. for each dropout rate, size of dense layers and activation function

for rate in List_Dropout_Rates:
  for dense_num in List_Dense:
    for acti in List_Activation:
      for i in range(2):#only run for 2 cross validation sets
        # Create the appropriate training and testing sets
        if i == 0:
          TrainImages = np.concatenate((Images1,Images2,Images3,Images4), axis=0)
          TrainLabels = np.concatenate((Labels1,Labels2,Labels3,Labels4), axis=0)
          TestImages = Images5
          TestLabels = Labels5
        elif i == 1:
          TrainImages = np.concatenate((Images1,Images2,Images3,Images5), axis=0)
          TrainLabels = np.concatenate((Labels1,Labels2,Labels3,Labels5), axis=0)
          TestImages = Images4
          TestLabels = Labels4
        elif i == 2:
          TrainImages = np.concatenate((Images1,Images2,Images4,Images5), axis=0)
          TrainLabels = np.concatenate((Labels1,Labels2,Labels4,Labels5), axis=0)
          TestImages = Images3
          TestLabels = Labels3
        elif i == 3:
          TrainImages = np.concatenate((Images1,Images3,Images4,Images5), axis=0)
          TrainLabels = np.concatenate((Labels1,Labels3,Labels4,Labels5), axis=0)
          TestImages = Images2
          TestLabels = Labels2
        else:
          TrainImages = np.concatenate((Images2,Images3,Images4,Images5), axis=0)
          TrainLabels = np.concatenate((Labels2,Labels3,Labels4,Labels5), axis=0)
          TestImages = Images1
          TestLabels = Labels1

        # Recompile model (need to do this everytime within the loop to reset model weights)
        #Dropout rate, dense layer size and activation function are used
        base_model = applications.VGG19(weights = "imagenet", include_top=False, input_shape = (128,128,3))
        x = base_model.output
        x = Flatten()(x)
        x = Dense(dense_num, activation=acti)(x)
        x = Dropout(rate)(x)
        x = Dense(dense_num, activation=acti)(x)
        x = Dropout(rate)(x)
        predictions = Dense(2, activation="softmax")(x) #Note that the predictions activation function is not varied across trials
        model = Model(inputs = base_model.input, outputs = predictions)
        adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, amsgrad=False)
        model.compile(loss = "categorical_crossentropy", optimizer = adam, metrics=["accuracy"])

        # Train model and evaluate performance
        print('We are now training cross-validation set #',i+1)
        Results = model.fit(TrainImages, TrainLabels, epochs=3, batch_size=64, validation_data=(TestImages,TestLabels), validation_freq=1)

        # Display and store performance results
        print("The Rate is " + str(rate) +", the dense number is " + str(dense_num) + ", the activation "+ str(acti))
        Results.history['loss'] = [round(j, 4) for j in Results.history['loss']]
        Results.history['accuracy'] = [round(j, 4) for j in Results.history['accuracy']]
        Results.history['val_loss'] = [round(j, 4) for j in Results.history['val_loss']]
        Results.history['val_accuracy'] = [round(j, 4) for j in Results.history['val_accuracy']]
        print('Training Loss:',Results.history['loss'])
        print('Training Accuracy:',Results.history['accuracy'])
        print('Validation Loss:',Results.history['val_loss'])
        print('Validation Accuracy:',Results.history['val_accuracy'])
        print('')
        results.append([Results.history['loss'],Results.history['accuracy'],Results.history['val_loss'],Results.history['val_accuracy']])#Update the results list
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 1s - loss: 5.3501 - accuracy: 0.4688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0860s vs `on_train_batch_end` time: 0.2021s). Check your callbacks.
# 13/13 [==============================] - 6s 447ms/step - loss: 2.2755 - accuracy: 0.6425 - val_loss: 0.4831 - val_accuracy: 0.8050
# Epoch 2/3
# 13/13 [==============================] - 4s 295ms/step - loss: 0.6727 - accuracy: 0.7425 - val_loss: 0.5257 - val_accuracy: 0.8000
# Epoch 3/3
# 13/13 [==============================] - 4s 295ms/step - loss: 0.4163 - accuracy: 0.8363 - val_loss: 0.3295 - val_accuracy: 0.8500
# The Rate is 0.25, the dense number is 128, the activation relu
# Training Loss: [2.2755, 0.6727, 0.4163]
# Training Accuracy: [0.6425, 0.7425, 0.8363]
# Validation Loss: [0.4831, 0.5257, 0.3295]
# Validation Accuracy: [0.805, 0.8, 0.85]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 5.2496 - accuracy: 0.5156WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0872s vs `on_train_batch_end` time: 0.2025s). Check your callbacks.
# 13/13 [==============================] - 4s 315ms/step - loss: 2.3454 - accuracy: 0.6413 - val_loss: 0.9228 - val_accuracy: 0.6950
# Epoch 2/3
# 13/13 [==============================] - 4s 298ms/step - loss: 0.8570 - accuracy: 0.7175 - val_loss: 0.5766 - val_accuracy: 0.7550
# Epoch 3/3
# 13/13 [==============================] - 4s 301ms/step - loss: 0.4960 - accuracy: 0.7775 - val_loss: 0.4942 - val_accuracy: 0.7850
# The Rate is 0.25, the dense number is 128, the activation relu
# Training Loss: [2.3454, 0.857, 0.496]
# Training Accuracy: [0.6413, 0.7175, 0.7775]
# Validation Loss: [0.9228, 0.5766, 0.4942]
# Validation Accuracy: [0.695, 0.755, 0.785]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 0.9839 - accuracy: 0.5078WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0892s vs `on_train_batch_end` time: 0.2044s). Check your callbacks.
# 13/13 [==============================] - 4s 318ms/step - loss: 0.7526 - accuracy: 0.6025 - val_loss: 0.5431 - val_accuracy: 0.7350
# Epoch 2/3
# 13/13 [==============================] - 4s 302ms/step - loss: 0.4860 - accuracy: 0.7613 - val_loss: 0.4002 - val_accuracy: 0.8300
# Epoch 3/3
# 13/13 [==============================] - 4s 304ms/step - loss: 0.3749 - accuracy: 0.8225 - val_loss: 0.2983 - val_accuracy: 0.8550
# The Rate is 0.25, the dense number is 128, the activation tanh
# Training Loss: [0.7526, 0.486, 0.3749]
# Training Accuracy: [0.6025, 0.7613, 0.8225]
# Validation Loss: [0.5431, 0.4002, 0.2983]
# Validation Accuracy: [0.735, 0.83, 0.855]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 0.9455 - accuracy: 0.5234WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0886s vs `on_train_batch_end` time: 0.2093s). Check your callbacks.
# 13/13 [==============================] - 4s 324ms/step - loss: 0.7518 - accuracy: 0.6212 - val_loss: 0.5481 - val_accuracy: 0.7250
# Epoch 2/3
# 13/13 [==============================] - 4s 310ms/step - loss: 0.5296 - accuracy: 0.7287 - val_loss: 0.4288 - val_accuracy: 0.8100
# Epoch 3/3
# 13/13 [==============================] - 4s 310ms/step - loss: 0.4067 - accuracy: 0.8125 - val_loss: 0.2940 - val_accuracy: 0.8950
# The Rate is 0.25, the dense number is 128, the activation tanh
# Training Loss: [0.7518, 0.5296, 0.4067]
# Training Accuracy: [0.6212, 0.7287, 0.8125]
# Validation Loss: [0.5481, 0.4288, 0.294]
# Validation Accuracy: [0.725, 0.81, 0.895]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 10.3510 - accuracy: 0.4531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0926s vs `on_train_batch_end` time: 0.2120s). Check your callbacks.
# 13/13 [==============================] - 4s 329ms/step - loss: 3.5815 - accuracy: 0.5650 - val_loss: 0.6006 - val_accuracy: 0.7450
# Epoch 2/3
# 13/13 [==============================] - 4s 315ms/step - loss: 0.8050 - accuracy: 0.7038 - val_loss: 0.3940 - val_accuracy: 0.8000
# Epoch 3/3
# 13/13 [==============================] - 4s 315ms/step - loss: 0.4548 - accuracy: 0.7912 - val_loss: 0.2924 - val_accuracy: 0.8550
# The Rate is 0.25, the dense number is 256, the activation relu
# Training Loss: [3.5815, 0.805, 0.4548]
# Training Accuracy: [0.565, 0.7038, 0.7912]
# Validation Loss: [0.6006, 0.394, 0.2924]
# Validation Accuracy: [0.745, 0.8, 0.855]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 3.6620 - accuracy: 0.5938WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0914s vs `on_train_batch_end` time: 0.2148s). Check your callbacks.
# 13/13 [==============================] - 5s 352ms/step - loss: 2.0053 - accuracy: 0.6350 - val_loss: 0.3933 - val_accuracy: 0.8400
# Epoch 2/3
# 13/13 [==============================] - 4s 318ms/step - loss: 0.6324 - accuracy: 0.8000 - val_loss: 0.2620 - val_accuracy: 0.8850
# Epoch 3/3
# 13/13 [==============================] - 4s 322ms/step - loss: 0.3642 - accuracy: 0.8637 - val_loss: 0.2084 - val_accuracy: 0.8950
# The Rate is 0.25, the dense number is 256, the activation relu
# Training Loss: [2.0053, 0.6324, 0.3642]
# Training Accuracy: [0.635, 0.8, 0.8637]
# Validation Loss: [0.3933, 0.262, 0.2084]
# Validation Accuracy: [0.84, 0.885, 0.895]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 0.8016 - accuracy: 0.5391WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0961s vs `on_train_batch_end` time: 0.2188s). Check your callbacks.
# 13/13 [==============================] - 4s 341ms/step - loss: 0.6578 - accuracy: 0.6237 - val_loss: 0.4728 - val_accuracy: 0.8000
# Epoch 2/3
# 13/13 [==============================] - 4s 330ms/step - loss: 0.4673 - accuracy: 0.7725 - val_loss: 0.3794 - val_accuracy: 0.8400
# Epoch 3/3
# 13/13 [==============================] - 4s 334ms/step - loss: 0.3039 - accuracy: 0.8737 - val_loss: 0.2959 - val_accuracy: 0.8650
# The Rate is 0.25, the dense number is 256, the activation tanh
# Training Loss: [0.6578, 0.4673, 0.3039]
# Training Accuracy: [0.6237, 0.7725, 0.8737]
# Validation Loss: [0.4728, 0.3794, 0.2959]
# Validation Accuracy: [0.8, 0.84, 0.865]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 0.8521 - accuracy: 0.5859WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0937s vs `on_train_batch_end` time: 0.2253s). Check your callbacks.
# 13/13 [==============================] - 5s 352ms/step - loss: 0.7609 - accuracy: 0.6062 - val_loss: 0.6071 - val_accuracy: 0.6600
# Epoch 2/3
# 13/13 [==============================] - 4s 341ms/step - loss: 0.5504 - accuracy: 0.7163 - val_loss: 0.3739 - val_accuracy: 0.8650
# Epoch 3/3
# 13/13 [==============================] - 4s 338ms/step - loss: 0.4105 - accuracy: 0.8100 - val_loss: 0.2809 - val_accuracy: 0.8950
# The Rate is 0.25, the dense number is 256, the activation tanh
# Training Loss: [0.7609, 0.5504, 0.4105]
# Training Accuracy: [0.6062, 0.7163, 0.81]
# Validation Loss: [0.6071, 0.3739, 0.2809]
# Validation Accuracy: [0.66, 0.865, 0.895]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 4.5780 - accuracy: 0.5078WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0956s vs `on_train_batch_end` time: 0.2243s). Check your callbacks.
# 13/13 [==============================] - 5s 350ms/step - loss: 2.2751 - accuracy: 0.6425 - val_loss: 0.3432 - val_accuracy: 0.8750
# Epoch 2/3
# 13/13 [==============================] - 4s 332ms/step - loss: 0.5666 - accuracy: 0.7875 - val_loss: 0.2383 - val_accuracy: 0.8950
# Epoch 3/3
# 13/13 [==============================] - 4s 329ms/step - loss: 0.3217 - accuracy: 0.8788 - val_loss: 0.1402 - val_accuracy: 0.9500
# The Rate is 0.25, the dense number is 512, the activation relu
# Training Loss: [2.2751, 0.5666, 0.3217]
# Training Accuracy: [0.6425, 0.7875, 0.8788]
# Validation Loss: [0.3432, 0.2383, 0.1402]
# Validation Accuracy: [0.875, 0.895, 0.95]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 4.6113 - accuracy: 0.5391WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0921s vs `on_train_batch_end` time: 0.2211s). Check your callbacks.
# 13/13 [==============================] - 4s 343ms/step - loss: 2.2143 - accuracy: 0.6600 - val_loss: 0.4212 - val_accuracy: 0.8400
# Epoch 2/3
# 13/13 [==============================] - 4s 324ms/step - loss: 0.6092 - accuracy: 0.7688 - val_loss: 0.2700 - val_accuracy: 0.8800
# Epoch 3/3
# 13/13 [==============================] - 4s 324ms/step - loss: 0.3812 - accuracy: 0.8550 - val_loss: 0.2000 - val_accuracy: 0.9300
# The Rate is 0.25, the dense number is 512, the activation relu
# Training Loss: [2.2143, 0.6092, 0.3812]
# Training Accuracy: [0.66, 0.7688, 0.855]
# Validation Loss: [0.4212, 0.27, 0.2]
# Validation Accuracy: [0.84, 0.88, 0.93]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 1.0582 - accuracy: 0.4453WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0939s vs `on_train_batch_end` time: 0.2196s). Check your callbacks.
# 13/13 [==============================] - 4s 341ms/step - loss: 0.8280 - accuracy: 0.5475 - val_loss: 0.6033 - val_accuracy: 0.6900
# Epoch 2/3
# 13/13 [==============================] - 4s 324ms/step - loss: 0.4994 - accuracy: 0.7688 - val_loss: 0.4272 - val_accuracy: 0.8050
# Epoch 3/3
# 13/13 [==============================] - 4s 325ms/step - loss: 0.4032 - accuracy: 0.8325 - val_loss: 0.3154 - val_accuracy: 0.8500
# The Rate is 0.25, the dense number is 512, the activation tanh
# Training Loss: [0.828, 0.4994, 0.4032]
# Training Accuracy: [0.5475, 0.7688, 0.8325]
# Validation Loss: [0.6033, 0.4272, 0.3154]
# Validation Accuracy: [0.69, 0.805, 0.85]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 0.9002 - accuracy: 0.4844WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0954s vs `on_train_batch_end` time: 0.2188s). Check your callbacks.
# 13/13 [==============================] - 4s 344ms/step - loss: 0.7052 - accuracy: 0.6212 - val_loss: 0.4685 - val_accuracy: 0.7450
# Epoch 2/3
# 13/13 [==============================] - 4s 327ms/step - loss: 0.4662 - accuracy: 0.7675 - val_loss: 0.3319 - val_accuracy: 0.8450
# Epoch 3/3
# 13/13 [==============================] - 4s 328ms/step - loss: 0.3477 - accuracy: 0.8425 - val_loss: 0.2859 - val_accuracy: 0.8900
# The Rate is 0.25, the dense number is 512, the activation tanh
# Training Loss: [0.7052, 0.4662, 0.3477]
# Training Accuracy: [0.6212, 0.7675, 0.8425]
# Validation Loss: [0.4685, 0.3319, 0.2859]
# Validation Accuracy: [0.745, 0.845, 0.89]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 6.4234 - accuracy: 0.5312WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0962s vs `on_train_batch_end` time: 0.2210s). Check your callbacks.
# 13/13 [==============================] - 5s 347ms/step - loss: 2.7060 - accuracy: 0.6075 - val_loss: 0.8784 - val_accuracy: 0.6750
# Epoch 2/3
# 13/13 [==============================] - 4s 330ms/step - loss: 0.8595 - accuracy: 0.6787 - val_loss: 0.4260 - val_accuracy: 0.8050
# Epoch 3/3
# 13/13 [==============================] - 4s 331ms/step - loss: 0.4771 - accuracy: 0.8037 - val_loss: 0.3721 - val_accuracy: 0.8350
# The Rate is 0.25, the dense number is 1024, the activation relu
# Training Loss: [2.706, 0.8595, 0.4771]
# Training Accuracy: [0.6075, 0.6787, 0.8037]
# Validation Loss: [0.8784, 0.426, 0.3721]
# Validation Accuracy: [0.675, 0.805, 0.835]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 5.7205 - accuracy: 0.5234WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0948s vs `on_train_batch_end` time: 0.2275s). Check your callbacks.
# 13/13 [==============================] - 5s 349ms/step - loss: 2.5715 - accuracy: 0.5950 - val_loss: 0.4820 - val_accuracy: 0.8000
# Epoch 2/3
# 13/13 [==============================] - 4s 334ms/step - loss: 0.6193 - accuracy: 0.7600 - val_loss: 0.3461 - val_accuracy: 0.8350
# Epoch 3/3
# 13/13 [==============================] - 4s 333ms/step - loss: 0.3712 - accuracy: 0.8400 - val_loss: 0.2751 - val_accuracy: 0.8750
# The Rate is 0.25, the dense number is 1024, the activation relu
# Training Loss: [2.5715, 0.6193, 0.3712]
# Training Accuracy: [0.595, 0.76, 0.84]
# Validation Loss: [0.482, 0.3461, 0.2751]
# Validation Accuracy: [0.8, 0.835, 0.875]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 0.7015 - accuracy: 0.5859WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0952s vs `on_train_batch_end` time: 0.2247s). Check your callbacks.
# 13/13 [==============================] - 5s 348ms/step - loss: 0.5953 - accuracy: 0.6787 - val_loss: 0.3687 - val_accuracy: 0.8450
# Epoch 2/3
# 13/13 [==============================] - 4s 331ms/step - loss: 0.3573 - accuracy: 0.8462 - val_loss: 0.2652 - val_accuracy: 0.9000
# Epoch 3/3
# 13/13 [==============================] - 4s 330ms/step - loss: 0.2501 - accuracy: 0.8988 - val_loss: 0.2102 - val_accuracy: 0.9050
# The Rate is 0.25, the dense number is 1024, the activation tanh
# Training Loss: [0.5953, 0.3573, 0.2501]
# Training Accuracy: [0.6787, 0.8462, 0.8988]
# Validation Loss: [0.3687, 0.2652, 0.2102]
# Validation Accuracy: [0.845, 0.9, 0.905]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 0.6561 - accuracy: 0.6328WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0961s vs `on_train_batch_end` time: 0.2222s). Check your callbacks.
# 13/13 [==============================] - 4s 346ms/step - loss: 0.6046 - accuracy: 0.6812 - val_loss: 0.3648 - val_accuracy: 0.8500
# Epoch 2/3
# 13/13 [==============================] - 4s 332ms/step - loss: 0.3763 - accuracy: 0.8288 - val_loss: 0.2645 - val_accuracy: 0.8850
# Epoch 3/3
# 13/13 [==============================] - 4s 331ms/step - loss: 0.2531 - accuracy: 0.8975 - val_loss: 0.2192 - val_accuracy: 0.9050
# The Rate is 0.25, the dense number is 1024, the activation tanh
# Training Loss: [0.6046, 0.3763, 0.2531]
# Training Accuracy: [0.6812, 0.8288, 0.8975]
# Validation Loss: [0.3648, 0.2645, 0.2192]
# Validation Accuracy: [0.85, 0.885, 0.905]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 13.4331 - accuracy: 0.4609WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0945s vs `on_train_batch_end` time: 0.2202s). Check your callbacks.
# 13/13 [==============================] - 4s 344ms/step - loss: 5.0844 - accuracy: 0.5475 - val_loss: 0.8999 - val_accuracy: 0.6900
# Epoch 2/3
# 13/13 [==============================] - 4s 327ms/step - loss: 1.4199 - accuracy: 0.5987 - val_loss: 0.6704 - val_accuracy: 0.7200
# Epoch 3/3
# 13/13 [==============================] - 4s 325ms/step - loss: 0.8667 - accuracy: 0.6413 - val_loss: 0.5274 - val_accuracy: 0.7350
# The Rate is 0.5, the dense number is 128, the activation relu
# Training Loss: [5.0844, 1.4199, 0.8667]
# Training Accuracy: [0.5475, 0.5987, 0.6413]
# Validation Loss: [0.8999, 0.6704, 0.5274]
# Validation Accuracy: [0.69, 0.72, 0.735]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 15.1176 - accuracy: 0.4766WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0975s vs `on_train_batch_end` time: 0.2207s). Check your callbacks.
# 13/13 [==============================] - 4s 342ms/step - loss: 5.7055 - accuracy: 0.5075 - val_loss: 0.8097 - val_accuracy: 0.5750
# Epoch 2/3
# 13/13 [==============================] - 4s 324ms/step - loss: 1.1028 - accuracy: 0.5525 - val_loss: 0.6398 - val_accuracy: 0.6100
# Epoch 3/3
# 13/13 [==============================] - 4s 325ms/step - loss: 0.8926 - accuracy: 0.5600 - val_loss: 0.5624 - val_accuracy: 0.7350
# The Rate is 0.5, the dense number is 128, the activation relu
# Training Loss: [5.7055, 1.1028, 0.8926]
# Training Accuracy: [0.5075, 0.5525, 0.56]
# Validation Loss: [0.8097, 0.6398, 0.5624]
# Validation Accuracy: [0.575, 0.61, 0.735]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 1.0677 - accuracy: 0.4531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0938s vs `on_train_batch_end` time: 0.2211s). Check your callbacks.
# 13/13 [==============================] - 5s 347ms/step - loss: 0.9280 - accuracy: 0.5462 - val_loss: 0.6156 - val_accuracy: 0.6700
# Epoch 2/3
# 13/13 [==============================] - 4s 330ms/step - loss: 0.6935 - accuracy: 0.6438 - val_loss: 0.5214 - val_accuracy: 0.7650
# Epoch 3/3
# 13/13 [==============================] - 4s 329ms/step - loss: 0.7010 - accuracy: 0.6650 - val_loss: 0.5293 - val_accuracy: 0.7200
# The Rate is 0.5, the dense number is 128, the activation tanh
# Training Loss: [0.928, 0.6935, 0.701]
# Training Accuracy: [0.5462, 0.6438, 0.665]
# Validation Loss: [0.6156, 0.5214, 0.5293]
# Validation Accuracy: [0.67, 0.765, 0.72]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 1.0911 - accuracy: 0.4688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0978s vs `on_train_batch_end` time: 0.2205s). Check your callbacks.
# 13/13 [==============================] - 4s 343ms/step - loss: 0.9823 - accuracy: 0.5350 - val_loss: 0.7094 - val_accuracy: 0.5950
# Epoch 2/3
# 13/13 [==============================] - 4s 329ms/step - loss: 0.8680 - accuracy: 0.5950 - val_loss: 0.5225 - val_accuracy: 0.7150
# Epoch 3/3
# 13/13 [==============================] - 4s 330ms/step - loss: 0.7446 - accuracy: 0.6275 - val_loss: 0.4117 - val_accuracy: 0.8100
# The Rate is 0.5, the dense number is 128, the activation tanh
# Training Loss: [0.9823, 0.868, 0.7446]
# Training Accuracy: [0.535, 0.595, 0.6275]
# Validation Loss: [0.7094, 0.5225, 0.4117]
# Validation Accuracy: [0.595, 0.715, 0.81]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 10.7660 - accuracy: 0.5312WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0949s vs `on_train_batch_end` time: 0.2182s). Check your callbacks.
# 13/13 [==============================] - 4s 345ms/step - loss: 4.3295 - accuracy: 0.5850 - val_loss: 0.6869 - val_accuracy: 0.6950
# Epoch 2/3
# 13/13 [==============================] - 4s 330ms/step - loss: 1.3463 - accuracy: 0.5587 - val_loss: 0.4954 - val_accuracy: 0.7400
# Epoch 3/3
# 13/13 [==============================] - 4s 328ms/step - loss: 0.8615 - accuracy: 0.6137 - val_loss: 0.4500 - val_accuracy: 0.7900
# The Rate is 0.5, the dense number is 256, the activation relu
# Training Loss: [4.3295, 1.3463, 0.8615]
# Training Accuracy: [0.585, 0.5587, 0.6137]
# Validation Loss: [0.6869, 0.4954, 0.45]
# Validation Accuracy: [0.695, 0.74, 0.79]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 7.5579 - accuracy: 0.5312WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0955s vs `on_train_batch_end` time: 0.2236s). Check your callbacks.
# 13/13 [==============================] - 5s 347ms/step - loss: 4.0255 - accuracy: 0.5700 - val_loss: 0.7336 - val_accuracy: 0.7000
# Epoch 2/3
# 13/13 [==============================] - 4s 331ms/step - loss: 1.3182 - accuracy: 0.5900 - val_loss: 0.5355 - val_accuracy: 0.7300
# Epoch 3/3
# 13/13 [==============================] - 4s 329ms/step - loss: 0.8685 - accuracy: 0.6100 - val_loss: 0.4632 - val_accuracy: 0.8000
# The Rate is 0.5, the dense number is 256, the activation relu
# Training Loss: [4.0255, 1.3182, 0.8685]
# Training Accuracy: [0.57, 0.59, 0.61]
# Validation Loss: [0.7336, 0.5355, 0.4632]
# Validation Accuracy: [0.7, 0.73, 0.8]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 1.1538 - accuracy: 0.5156WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0952s vs `on_train_batch_end` time: 0.2192s). Check your callbacks.
# 13/13 [==============================] - 4s 344ms/step - loss: 0.9198 - accuracy: 0.5813 - val_loss: 0.5665 - val_accuracy: 0.7050
# Epoch 2/3
# 13/13 [==============================] - 4s 333ms/step - loss: 0.6679 - accuracy: 0.6787 - val_loss: 0.4410 - val_accuracy: 0.7600
# Epoch 3/3
# 13/13 [==============================] - 4s 330ms/step - loss: 0.5694 - accuracy: 0.7387 - val_loss: 0.3779 - val_accuracy: 0.8100
# The Rate is 0.5, the dense number is 256, the activation tanh
# Training Loss: [0.9198, 0.6679, 0.5694]
# Training Accuracy: [0.5813, 0.6787, 0.7387]
# Validation Loss: [0.5665, 0.441, 0.3779]
# Validation Accuracy: [0.705, 0.76, 0.81]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 1.0037 - accuracy: 0.4609WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0952s vs `on_train_batch_end` time: 0.2241s). Check your callbacks.
# 13/13 [==============================] - 5s 350ms/step - loss: 0.9440 - accuracy: 0.5500 - val_loss: 0.5740 - val_accuracy: 0.6950
# Epoch 2/3
# 13/13 [==============================] - 4s 333ms/step - loss: 0.7051 - accuracy: 0.6500 - val_loss: 0.4653 - val_accuracy: 0.7800
# Epoch 3/3
# 13/13 [==============================] - 4s 333ms/step - loss: 0.6212 - accuracy: 0.7038 - val_loss: 0.3591 - val_accuracy: 0.8450
# The Rate is 0.5, the dense number is 256, the activation tanh
# Training Loss: [0.944, 0.7051, 0.6212]
# Training Accuracy: [0.55, 0.65, 0.7038]
# Validation Loss: [0.574, 0.4653, 0.3591]
# Validation Accuracy: [0.695, 0.78, 0.845]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 9.6107 - accuracy: 0.4922WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0935s vs `on_train_batch_end` time: 0.2232s). Check your callbacks.
# 13/13 [==============================] - 5s 350ms/step - loss: 4.3119 - accuracy: 0.5575 - val_loss: 0.6782 - val_accuracy: 0.6700
# Epoch 2/3
# 13/13 [==============================] - 4s 333ms/step - loss: 1.3427 - accuracy: 0.5975 - val_loss: 0.5180 - val_accuracy: 0.7350
# Epoch 3/3
# 13/13 [==============================] - 4s 332ms/step - loss: 0.7416 - accuracy: 0.6762 - val_loss: 0.5164 - val_accuracy: 0.7700
# The Rate is 0.5, the dense number is 512, the activation relu
# Training Loss: [4.3119, 1.3427, 0.7416]
# Training Accuracy: [0.5575, 0.5975, 0.6762]
# Validation Loss: [0.6782, 0.518, 0.5164]
# Validation Accuracy: [0.67, 0.735, 0.77]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 9.9629 - accuracy: 0.4297WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0978s vs `on_train_batch_end` time: 0.2236s). Check your callbacks.
# 13/13 [==============================] - 5s 351ms/step - loss: 4.5917 - accuracy: 0.5050 - val_loss: 0.6595 - val_accuracy: 0.6600
# Epoch 2/3
# 13/13 [==============================] - 4s 335ms/step - loss: 1.4107 - accuracy: 0.5362 - val_loss: 0.5653 - val_accuracy: 0.7100
# Epoch 3/3
# 13/13 [==============================] - 4s 333ms/step - loss: 0.8298 - accuracy: 0.6150 - val_loss: 0.4654 - val_accuracy: 0.8000
# The Rate is 0.5, the dense number is 512, the activation relu
# Training Loss: [4.5917, 1.4107, 0.8298]
# Training Accuracy: [0.505, 0.5362, 0.615]
# Validation Loss: [0.6595, 0.5653, 0.4654]
# Validation Accuracy: [0.66, 0.71, 0.8]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 0.8611 - accuracy: 0.5625WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0938s vs `on_train_batch_end` time: 0.2272s). Check your callbacks.
# 13/13 [==============================] - 5s 349ms/step - loss: 0.8064 - accuracy: 0.6012 - val_loss: 0.4924 - val_accuracy: 0.7500
# Epoch 2/3
# 13/13 [==============================] - 4s 333ms/step - loss: 0.7518 - accuracy: 0.6350 - val_loss: 0.4433 - val_accuracy: 0.8050
# Epoch 3/3
# 13/13 [==============================] - 4s 335ms/step - loss: 0.6159 - accuracy: 0.7163 - val_loss: 0.3935 - val_accuracy: 0.8200
# The Rate is 0.5, the dense number is 512, the activation tanh
# Training Loss: [0.8064, 0.7518, 0.6159]
# Training Accuracy: [0.6012, 0.635, 0.7163]
# Validation Loss: [0.4924, 0.4433, 0.3935]
# Validation Accuracy: [0.75, 0.805, 0.82]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 1.1093 - accuracy: 0.4844WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0951s vs `on_train_batch_end` time: 0.2236s). Check your callbacks.
# 13/13 [==============================] - 5s 348ms/step - loss: 0.9760 - accuracy: 0.5412 - val_loss: 0.6703 - val_accuracy: 0.5900
# Epoch 2/3
# 13/13 [==============================] - 4s 330ms/step - loss: 0.8010 - accuracy: 0.6100 - val_loss: 0.4962 - val_accuracy: 0.7550
# Epoch 3/3
# 13/13 [==============================] - 4s 334ms/step - loss: 0.6647 - accuracy: 0.6737 - val_loss: 0.4168 - val_accuracy: 0.8000
# The Rate is 0.5, the dense number is 512, the activation tanh
# Training Loss: [0.976, 0.801, 0.6647]
# Training Accuracy: [0.5412, 0.61, 0.6737]
# Validation Loss: [0.6703, 0.4962, 0.4168]
# Validation Accuracy: [0.59, 0.755, 0.8]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 10.3850 - accuracy: 0.4453WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0988s vs `on_train_batch_end` time: 0.2251s). Check your callbacks.
# 13/13 [==============================] - 5s 351ms/step - loss: 4.3344 - accuracy: 0.5275 - val_loss: 0.7870 - val_accuracy: 0.6400
# Epoch 2/3
# 13/13 [==============================] - 4s 334ms/step - loss: 1.2485 - accuracy: 0.5800 - val_loss: 0.5100 - val_accuracy: 0.7350
# Epoch 3/3
# 13/13 [==============================] - 4s 332ms/step - loss: 0.8546 - accuracy: 0.6100 - val_loss: 0.4408 - val_accuracy: 0.8500
# The Rate is 0.5, the dense number is 1024, the activation relu
# Training Loss: [4.3344, 1.2485, 0.8546]
# Training Accuracy: [0.5275, 0.58, 0.61]
# Validation Loss: [0.787, 0.51, 0.4408]
# Validation Accuracy: [0.64, 0.735, 0.85]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 9.1135 - accuracy: 0.5234 WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0947s vs `on_train_batch_end` time: 0.2251s). Check your callbacks.
# 13/13 [==============================] - 5s 351ms/step - loss: 4.1761 - accuracy: 0.5450 - val_loss: 0.7463 - val_accuracy: 0.6850
# Epoch 2/3
# 13/13 [==============================] - 4s 335ms/step - loss: 1.3433 - accuracy: 0.6000 - val_loss: 0.4836 - val_accuracy: 0.8000
# Epoch 3/3
# 13/13 [==============================] - 4s 334ms/step - loss: 0.8400 - accuracy: 0.6388 - val_loss: 0.4318 - val_accuracy: 0.7900
# The Rate is 0.5, the dense number is 1024, the activation relu
# Training Loss: [4.1761, 1.3433, 0.84]
# Training Accuracy: [0.545, 0.6, 0.6388]
# Validation Loss: [0.7463, 0.4836, 0.4318]
# Validation Accuracy: [0.685, 0.8, 0.79]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 0.8928 - accuracy: 0.5156WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0914s vs `on_train_batch_end` time: 0.2237s). Check your callbacks.
# 13/13 [==============================] - 5s 350ms/step - loss: 0.7763 - accuracy: 0.6012 - val_loss: 0.4122 - val_accuracy: 0.8350
# Epoch 2/3
# 13/13 [==============================] - 4s 332ms/step - loss: 0.5948 - accuracy: 0.7237 - val_loss: 0.2998 - val_accuracy: 0.8700
# Epoch 3/3
# 13/13 [==============================] - 4s 333ms/step - loss: 0.4470 - accuracy: 0.8213 - val_loss: 0.2802 - val_accuracy: 0.8750
# The Rate is 0.5, the dense number is 1024, the activation tanh
# Training Loss: [0.7763, 0.5948, 0.447]
# Training Accuracy: [0.6012, 0.7237, 0.8213]
# Validation Loss: [0.4122, 0.2998, 0.2802]
# Validation Accuracy: [0.835, 0.87, 0.875]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 1.0147 - accuracy: 0.4766WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0938s vs `on_train_batch_end` time: 0.2256s). Check your callbacks.
# 13/13 [==============================] - 5s 349ms/step - loss: 0.8799 - accuracy: 0.5600 - val_loss: 0.4670 - val_accuracy: 0.7600
# Epoch 2/3
# 13/13 [==============================] - 4s 334ms/step - loss: 0.5810 - accuracy: 0.7312 - val_loss: 0.3294 - val_accuracy: 0.8400
# Epoch 3/3
# 13/13 [==============================] - 4s 333ms/step - loss: 0.4708 - accuracy: 0.7825 - val_loss: 0.2730 - val_accuracy: 0.8800
# The Rate is 0.5, the dense number is 1024, the activation tanh
# Training Loss: [0.8799, 0.581, 0.4708]
# Training Accuracy: [0.56, 0.7312, 0.7825]
# Validation Loss: [0.467, 0.3294, 0.273]
# Validation Accuracy: [0.76, 0.84, 0.88]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 22.0461 - accuracy: 0.5703WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0918s vs `on_train_batch_end` time: 0.2212s). Check your callbacks.
# 13/13 [==============================] - 4s 345ms/step - loss: 9.2414 - accuracy: 0.5337 - val_loss: 0.7521 - val_accuracy: 0.6300
# Epoch 2/3
# 13/13 [==============================] - 4s 329ms/step - loss: 2.5869 - accuracy: 0.5213 - val_loss: 0.5897 - val_accuracy: 0.7000
# Epoch 3/3
# 13/13 [==============================] - 4s 328ms/step - loss: 1.3330 - accuracy: 0.5288 - val_loss: 0.6068 - val_accuracy: 0.6800
# The Rate is 0.75, the dense number is 128, the activation relu
# Training Loss: [9.2414, 2.5869, 1.333]
# Training Accuracy: [0.5337, 0.5213, 0.5288]
# Validation Loss: [0.7521, 0.5897, 0.6068]
# Validation Accuracy: [0.63, 0.7, 0.68]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 15.7048 - accuracy: 0.5156WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0922s vs `on_train_batch_end` time: 0.2211s). Check your callbacks.
# 13/13 [==============================] - 4s 345ms/step - loss: 8.0255 - accuracy: 0.5437 - val_loss: 0.9597 - val_accuracy: 0.5900
# Epoch 2/3
# 13/13 [==============================] - 4s 330ms/step - loss: 2.3697 - accuracy: 0.5362 - val_loss: 0.7348 - val_accuracy: 0.5700
# Epoch 3/3
# 13/13 [==============================] - 4s 327ms/step - loss: 1.1939 - accuracy: 0.5800 - val_loss: 0.6192 - val_accuracy: 0.6650
# The Rate is 0.75, the dense number is 128, the activation relu
# Training Loss: [8.0255, 2.3697, 1.1939]
# Training Accuracy: [0.5437, 0.5362, 0.58]
# Validation Loss: [0.9597, 0.7348, 0.6192]
# Validation Accuracy: [0.59, 0.57, 0.665]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 1.7502 - accuracy: 0.3984WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0961s vs `on_train_batch_end` time: 0.2213s). Check your callbacks.
# 13/13 [==============================] - 4s 344ms/step - loss: 1.4032 - accuracy: 0.5038 - val_loss: 0.7654 - val_accuracy: 0.5350
# Epoch 2/3
# 13/13 [==============================] - 4s 329ms/step - loss: 1.3488 - accuracy: 0.5125 - val_loss: 0.6504 - val_accuracy: 0.6150
# Epoch 3/3
# 13/13 [==============================] - 4s 330ms/step - loss: 1.2909 - accuracy: 0.5288 - val_loss: 0.6119 - val_accuracy: 0.6300
# The Rate is 0.75, the dense number is 128, the activation tanh
# Training Loss: [1.4032, 1.3488, 1.2909]
# Training Accuracy: [0.5038, 0.5125, 0.5288]
# Validation Loss: [0.7654, 0.6504, 0.6119]
# Validation Accuracy: [0.535, 0.615, 0.63]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 1.7092 - accuracy: 0.4531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0946s vs `on_train_batch_end` time: 0.2229s). Check your callbacks.
# 13/13 [==============================] - 4s 345ms/step - loss: 1.5547 - accuracy: 0.4700 - val_loss: 0.6776 - val_accuracy: 0.6350
# Epoch 2/3
# 13/13 [==============================] - 4s 331ms/step - loss: 1.3155 - accuracy: 0.5350 - val_loss: 0.6148 - val_accuracy: 0.6650
# Epoch 3/3
# 13/13 [==============================] - 4s 330ms/step - loss: 1.2728 - accuracy: 0.5550 - val_loss: 0.5224 - val_accuracy: 0.7550
# The Rate is 0.75, the dense number is 128, the activation tanh
# Training Loss: [1.5547, 1.3155, 1.2728]
# Training Accuracy: [0.47, 0.535, 0.555]
# Validation Loss: [0.6776, 0.6148, 0.5224]
# Validation Accuracy: [0.635, 0.665, 0.755]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 27.4967 - accuracy: 0.4219WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0991s vs `on_train_batch_end` time: 0.2224s). Check your callbacks.
# 13/13 [==============================] - 5s 349ms/step - loss: 11.4303 - accuracy: 0.5312 - val_loss: 0.8466 - val_accuracy: 0.6100
# Epoch 2/3
# 13/13 [==============================] - 4s 330ms/step - loss: 2.6387 - accuracy: 0.5450 - val_loss: 0.5629 - val_accuracy: 0.6650
# Epoch 3/3
# 13/13 [==============================] - 4s 330ms/step - loss: 1.7424 - accuracy: 0.5138 - val_loss: 0.5961 - val_accuracy: 0.7100
# The Rate is 0.75, the dense number is 256, the activation relu
# Training Loss: [11.4303, 2.6387, 1.7424]
# Training Accuracy: [0.5312, 0.545, 0.5138]
# Validation Loss: [0.8466, 0.5629, 0.5961]
# Validation Accuracy: [0.61, 0.665, 0.71]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 24.1111 - accuracy: 0.4219WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0965s vs `on_train_batch_end` time: 0.2223s). Check your callbacks.
# 13/13 [==============================] - 4s 345ms/step - loss: 10.7581 - accuracy: 0.4737 - val_loss: 0.9020 - val_accuracy: 0.5950
# Epoch 2/3
# 13/13 [==============================] - 4s 330ms/step - loss: 2.7204 - accuracy: 0.4913 - val_loss: 0.7499 - val_accuracy: 0.5200
# Epoch 3/3
# 13/13 [==============================] - 4s 330ms/step - loss: 1.4448 - accuracy: 0.5213 - val_loss: 0.6368 - val_accuracy: 0.6050
# The Rate is 0.75, the dense number is 256, the activation relu
# Training Loss: [10.7581, 2.7204, 1.4448]
# Training Accuracy: [0.4737, 0.4913, 0.5213]
# Validation Loss: [0.902, 0.7499, 0.6368]
# Validation Accuracy: [0.595, 0.52, 0.605]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 1.5659 - accuracy: 0.4453WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0959s vs `on_train_batch_end` time: 0.2240s). Check your callbacks.
# 13/13 [==============================] - 4s 346ms/step - loss: 1.4216 - accuracy: 0.5138 - val_loss: 0.7577 - val_accuracy: 0.5550
# Epoch 2/3
# 13/13 [==============================] - 4s 331ms/step - loss: 1.3911 - accuracy: 0.4975 - val_loss: 0.6466 - val_accuracy: 0.6200
# Epoch 3/3
# 13/13 [==============================] - 4s 330ms/step - loss: 1.4749 - accuracy: 0.5125 - val_loss: 0.5247 - val_accuracy: 0.7500
# The Rate is 0.75, the dense number is 256, the activation tanh
# Training Loss: [1.4216, 1.3911, 1.4749]
# Training Accuracy: [0.5138, 0.4975, 0.5125]
# Validation Loss: [0.7577, 0.6466, 0.5247]
# Validation Accuracy: [0.555, 0.62, 0.75]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 1.7376 - accuracy: 0.4453WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0934s vs `on_train_batch_end` time: 0.2205s). Check your callbacks.
# 13/13 [==============================] - 5s 347ms/step - loss: 1.4946 - accuracy: 0.5150 - val_loss: 0.6219 - val_accuracy: 0.6200
# Epoch 2/3
# 13/13 [==============================] - 4s 333ms/step - loss: 1.2871 - accuracy: 0.5638 - val_loss: 0.5022 - val_accuracy: 0.7600
# Epoch 3/3
# 13/13 [==============================] - 4s 331ms/step - loss: 1.2543 - accuracy: 0.5888 - val_loss: 0.4913 - val_accuracy: 0.7650
# The Rate is 0.75, the dense number is 256, the activation tanh
# Training Loss: [1.4946, 1.2871, 1.2543]
# Training Accuracy: [0.515, 0.5638, 0.5888]
# Validation Loss: [0.6219, 0.5022, 0.4913]
# Validation Accuracy: [0.62, 0.76, 0.765]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 20.2894 - accuracy: 0.4766WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0968s vs `on_train_batch_end` time: 0.2239s). Check your callbacks.
# 13/13 [==============================] - 5s 348ms/step - loss: 10.9920 - accuracy: 0.5163 - val_loss: 0.7258 - val_accuracy: 0.6850
# Epoch 2/3
# 13/13 [==============================] - 4s 333ms/step - loss: 2.9492 - accuracy: 0.5325 - val_loss: 0.7074 - val_accuracy: 0.5400
# Epoch 3/3
# 13/13 [==============================] - 4s 331ms/step - loss: 1.8466 - accuracy: 0.5025 - val_loss: 0.6744 - val_accuracy: 0.5750
# The Rate is 0.75, the dense number is 512, the activation relu
# Training Loss: [10.992, 2.9492, 1.8466]
# Training Accuracy: [0.5163, 0.5325, 0.5025]
# Validation Loss: [0.7258, 0.7074, 0.6744]
# Validation Accuracy: [0.685, 0.54, 0.575]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 17.4504 - accuracy: 0.5078WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0975s vs `on_train_batch_end` time: 0.2255s). Check your callbacks.
# 13/13 [==============================] - 5s 349ms/step - loss: 10.1233 - accuracy: 0.5025 - val_loss: 0.6678 - val_accuracy: 0.6900
# Epoch 2/3
# 13/13 [==============================] - 4s 332ms/step - loss: 2.7587 - accuracy: 0.5275 - val_loss: 0.6082 - val_accuracy: 0.6800
# Epoch 3/3
# 13/13 [==============================] - 4s 330ms/step - loss: 1.5266 - accuracy: 0.5450 - val_loss: 0.6172 - val_accuracy: 0.6650
# The Rate is 0.75, the dense number is 512, the activation relu
# Training Loss: [10.1233, 2.7587, 1.5266]
# Training Accuracy: [0.5025, 0.5275, 0.545]
# Validation Loss: [0.6678, 0.6082, 0.6172]
# Validation Accuracy: [0.69, 0.68, 0.665]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 1.1471 - accuracy: 0.5000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0930s vs `on_train_batch_end` time: 0.2261s). Check your callbacks.
# 13/13 [==============================] - 5s 349ms/step - loss: 1.2441 - accuracy: 0.5475 - val_loss: 0.6105 - val_accuracy: 0.6850
# Epoch 2/3
# 13/13 [==============================] - 4s 334ms/step - loss: 1.2436 - accuracy: 0.5625 - val_loss: 0.5171 - val_accuracy: 0.7600
# Epoch 3/3
# 13/13 [==============================] - 4s 333ms/step - loss: 1.1743 - accuracy: 0.5675 - val_loss: 0.5352 - val_accuracy: 0.7250
# The Rate is 0.75, the dense number is 512, the activation tanh
# Training Loss: [1.2441, 1.2436, 1.1743]
# Training Accuracy: [0.5475, 0.5625, 0.5675]
# Validation Loss: [0.6105, 0.5171, 0.5352]
# Validation Accuracy: [0.685, 0.76, 0.725]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 1.4694 - accuracy: 0.5000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1039s vs `on_train_batch_end` time: 0.2234s). Check your callbacks.
# 13/13 [==============================] - 5s 350ms/step - loss: 1.4344 - accuracy: 0.4825 - val_loss: 0.5693 - val_accuracy: 0.6900
# Epoch 2/3
# 13/13 [==============================] - 4s 334ms/step - loss: 1.2369 - accuracy: 0.5437 - val_loss: 0.5094 - val_accuracy: 0.7100
# Epoch 3/3
# 13/13 [==============================] - 4s 333ms/step - loss: 1.2067 - accuracy: 0.5587 - val_loss: 0.4486 - val_accuracy: 0.7900
# The Rate is 0.75, the dense number is 512, the activation tanh
# Training Loss: [1.4344, 1.2369, 1.2067]
# Training Accuracy: [0.4825, 0.5437, 0.5587]
# Validation Loss: [0.5693, 0.5094, 0.4486]
# Validation Accuracy: [0.69, 0.71, 0.79]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 2s - loss: 16.1526 - accuracy: 0.5469WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0924s vs `on_train_batch_end` time: 0.2241s). Check your callbacks.
# 13/13 [==============================] - 5s 350ms/step - loss: 9.2845 - accuracy: 0.5537 - val_loss: 1.0589 - val_accuracy: 0.5700
# Epoch 2/3
# 13/13 [==============================] - 4s 332ms/step - loss: 2.7965 - accuracy: 0.4938 - val_loss: 0.6298 - val_accuracy: 0.6450
# Epoch 3/3
# 13/13 [==============================] - 4s 331ms/step - loss: 1.4657 - accuracy: 0.5288 - val_loss: 0.5981 - val_accuracy: 0.7150
# The Rate is 0.75, the dense number is 1024, the activation relu
# Training Loss: [9.2845, 2.7965, 1.4657]
# Training Accuracy: [0.5537, 0.4938, 0.5288]
# Validation Loss: [1.0589, 0.6298, 0.5981]
# Validation Accuracy: [0.57, 0.645, 0.715]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 20.6203 - accuracy: 0.4453WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0975s vs `on_train_batch_end` time: 0.2236s). Check your callbacks.
# 13/13 [==============================] - 5s 350ms/step - loss: 9.8024 - accuracy: 0.5188 - val_loss: 0.6906 - val_accuracy: 0.6550
# Epoch 2/3
# 13/13 [==============================] - 4s 334ms/step - loss: 2.9030 - accuracy: 0.5125 - val_loss: 0.6549 - val_accuracy: 0.5950
# Epoch 3/3
# 13/13 [==============================] - 4s 332ms/step - loss: 1.5137 - accuracy: 0.5387 - val_loss: 0.6172 - val_accuracy: 0.6400
# The Rate is 0.75, the dense number is 1024, the activation relu
# Training Loss: [9.8024, 2.903, 1.5137]
# Training Accuracy: [0.5188, 0.5125, 0.5387]
# Validation Loss: [0.6906, 0.6549, 0.6172]
# Validation Accuracy: [0.655, 0.595, 0.64]
#
# We are now training cross-validation set # 1
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 1.3951 - accuracy: 0.5078WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0971s vs `on_train_batch_end` time: 0.2256s). Check your callbacks.
# 13/13 [==============================] - 5s 351ms/step - loss: 1.4173 - accuracy: 0.5200 - val_loss: 0.6939 - val_accuracy: 0.6400
# Epoch 2/3
# 13/13 [==============================] - 4s 336ms/step - loss: 1.2195 - accuracy: 0.5525 - val_loss: 0.4410 - val_accuracy: 0.7900
# Epoch 3/3
# 13/13 [==============================] - 4s 336ms/step - loss: 1.0896 - accuracy: 0.6087 - val_loss: 0.4160 - val_accuracy: 0.8100
# The Rate is 0.75, the dense number is 1024, the activation tanh
# Training Loss: [1.4173, 1.2195, 1.0896]
# Training Accuracy: [0.52, 0.5525, 0.6087]
# Validation Loss: [0.6939, 0.441, 0.416]
# Validation Accuracy: [0.64, 0.79, 0.81]
#
# We are now training cross-validation set # 2
# Epoch 1/3
#  2/13 [===>..........................] - ETA: 3s - loss: 1.3808 - accuracy: 0.5000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0967s vs `on_train_batch_end` time: 0.2243s). Check your callbacks.
# 13/13 [==============================] - 5s 351ms/step - loss: 1.3331 - accuracy: 0.5013 - val_loss: 0.6232 - val_accuracy: 0.6650
# Epoch 2/3
# 13/13 [==============================] - 4s 334ms/step - loss: 1.3487 - accuracy: 0.5250 - val_loss: 0.5874 - val_accuracy: 0.7000
# Epoch 3/3
# 13/13 [==============================] - 4s 334ms/step - loss: 1.2702 - accuracy: 0.5638 - val_loss: 0.5826 - val_accuracy: 0.6550
# The Rate is 0.75, the dense number is 1024, the activation tanh
# Training Loss: [1.3331, 1.3487, 1.2702]
# Training Accuracy: [0.5013, 0.525, 0.5638]
# Validation Loss: [0.6232, 0.5874, 0.5826]
# Validation Accuracy: [0.665, 0.7, 0.655]

# %%
#This code allows you to see the testing and validation accuarcy and losses for a given Dropout rate, Dense layer size and activation function

#Libraries needed
import matplotlib.pyplot as plt

List_Dropout_Rates = [0.25,0.50,0.75] #all the drop out rates used
List_Dense = [128,256,512,1024] #number of neurons in Dense layer
List_Activation = ["relu","tanh"] #the different activation functions used
results_dict = dict()
i = 0
for rate in List_Dropout_Rates:
  results_dict[rate] = dict()
  for dense_num in List_Dense:
    results_dict[rate][dense_num] = dict()
    for acti in List_Activation:
      results_dict[rate][dense_num][acti] = []
      for _ in range(2):
        results_dict[rate][dense_num][acti].append(results[i])
        i+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ed518149f536> in <module>()
#      16       results_dict[rate][dense_num][acti] = []
#      17       for _ in range(2):
# ---> 18         results_dict[rate][dense_num][acti].append(results[i])
#      19         i+=1
#      20
#
# NameError: name 'results' is not defined

# %%
cont = True
while cont:
  #now ask the user:
  drop = float(input("What Dropout level would you like? Options are: "+ str(List_Dropout_Rates)))
  dense = int(input("What Dense size would you like? Options are: "+ str(List_Dense)))
  activ = input("What activation function would you like? Options are: "+ str(List_Activation))
  print("Fetching the data you requested")

  ##code for graphs
  fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2)
  fig.set_figheight(10)
  fig.set_figwidth(10)
  fig.subplots_adjust(hspace=.4, wspace=.4)
  for validation in range(2):
    print("Results from Validation Test #",validation+1)
    loss = results_dict[drop][dense][activ][validation][0]
    acc = results_dict[drop][dense][activ][validation][1]
    val_loss = results_dict[drop][dense][activ][validation][2]
    val_acc = results_dict[drop][dense][activ][validation][3]
    print("Test Loss was ",loss)
    print("Test Accuracy was ",acc)
    print("Validation Loss was ",val_loss)
    print("Validation Accuracy was ",val_acc)
    print()
    ax1.plot(loss,label = "Training Loss from Validation # " + str(validation+1))
    ax2.plot(acc,label = "Training Accuracy from Validation # " + str(validation+1))
    ax3.plot(val_loss,label = "Validation Loss from Validation # " + str(validation+1))
    ax4.plot(val_acc,label = "Validation Accuracy from Validation # " + str(validation+1))
  ax1.legend(loc="upper center")
  ax2.legend(loc="upper center")
  ax3.legend(loc="upper center")
  ax4.legend(loc="upper center")
  print("\n\n")
  user = input("Would you like to continue? (y/n)")
  cont = True if user.lower() == "y" else False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-75c15e1cc54d> in <module>()
#       2 while cont:
#       3   #now ask the user:
# ----> 4   drop = float(input("What Dropout level would you like? Options are: "+ str(List_Dropout_Rates)))
#       5   dense = int(input("What Dense size would you like? Options are: "+ str(List_Dense)))
#       6   activ = input("What activation function would you like? Options are: "+ str(List_Activation))
#
# NameError: name 'List_Dropout_Rates' is not defined

# %%
print(results_dict[.75][1024]['tanh'][1])
# Out:
# [[1.3331, 1.3487, 1.2702], [0.5013, 0.525, 0.5638], [0.6232, 0.5874, 0.5826], [0.665, 0.7, 0.655]]
